# %% [markdown]
# This notebook contains a step-by-step Python implementation of Christopher Liem's professional resume.

# %% [markdown]
# # 1. Text Variables
# Contains all text in the resume

# %%
# Text Variables
header = 'This resume was generated in Python. For full source code, visit my repository at https://github.com/chrisl93/Resume.'
name = 'CHRISTOPHER LIEM'
email = 'chrisliem93@gmail.com'
phone = '(408) 471-8411'
header_edu = 'EDUCATION'
edu_major = 'Undergraduate of Electrical Engineering & Automation'
edu_school = 'Tsinghua University, Beijing, China'
edu_date = 'June 2021'
header_work1 = 'WORK'
header_work2 = 'EXPERIENCE'
work_title1 = 'Undergraduate Research Assistant - Intelligent '
work_title1_2 = 'Fault Detection and Health Assessment of Photovoltaic Systems  |'
work_place1 = 'Tsinghua University, Beijing, China'
work_date1 = 'Oct 2020 - Jun 2021'
work_desc1 = '\u2022 Designed, developed and verified a metaheuristic approach to create\n  performance prediction models of photovoltaic systems in MATLAB\n' \
            '\u2022 Created an online fault monitoring implementation of photovoltaic systems\n  using the XGBoost machine learning algorithm in Python\n' \
            '\u2022 Trained a neural network for fault detection in photovoltaic systems\n' \
            '\u2022 Established procedures for analyzing and interpreting simulation results'
work_title2 = 'Summer Internship'
work_place2 = 'PT AIM, Semarang, Indonesia'
work_date2 = 'August 2020'
work_desc2 = '\u2022 Designed and implemented a program on Python to automatically update\n  inventory of raw materials, reducing time spent by 97%\n' \
            '\u2022 Completed periodic laboratory analysis and product quality assurance'
work_title3 = 'Summer Internship  |  WanTCom Inc,'
work_place3 = 'Chanhassen, MN, USA'
work_date3 = 'Jun 2019 - Aug 2019'
work_desc3 = '\u2022 Trained in materials and components, industry standards, test equipment\n  operation and product development and manufacturing procedures\n' \
            '\u2022 Monitored the electrical characteristics of various amplifiers from the\n  assembly line to ensure acceptable quality standards\n' \
            '\u2022 Assembled a low noise amplifier for an existing customer and established\n  a plan to test performance and verify adherence to electrical specifications'
work_title4 = 'Summer Internship  |  Tsinghua Sichuan Energy'
work_place4 = 'Internet Research Institute, Chengdu, China'
work_date4 = 'August 2018'
work_desc4 = '\u2022 Collaborated with project members to successfully convert an analog\n  rotameter to a digital version using Python and the Google AIY Vision Kit\n' \
            '\u2022 Decomposed an image processing problem and utilized MATLAB tools to\n  independently develop an analytical solution'
header_other = 'PROJECTS'
other1 = 'Designed a solar tracker in C using the MSP430 microcontroller'
header_skill = 'SUMMARY OF'
header_skill2 = 'SKILLS'
skill_title1 = 'Programming'
skill_desc1 = 'Python, MATLAB, Java, C, Verilog HDL'
skill_title2 = 'Simulation Software'
skill_desc2 = 'AutoCAD, Solidworks, NI Multisim, Simulink'
skill_title3 = 'Languages'
skill_desc3 = 'English, Mandarin Chinese, Bahasa Indonesia'
header_cert = 'CERTIFICATIONS'
cert_title1 = 'Neural Networks and Deep Learning'
cert_title1_2 = 'by DeepLearning.AI'
cert_date1 = 'April 2021'
cert_title2 = 'Improving Deep Neural Networks: Hyperparameter\n  Tuning, Regularization and Optimization'
cert_date2 = 'July 2021'

# %% [markdown]
# # 2. Design
# Includes fonts and styles

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Font
import matplotlib.font_manager

from IPython.core.display import HTML

# # Browse fonts
# def make_html(fontname):
#     return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

# # code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])
# chosen_fonts = set(['Garamond', 'Helvetica', 'Times New Roman', 'Georgia', 'Arial', 'Calibri', 'Avenir Next', 'Muna'])
# code = "\n".join([make_html(font) for font in sorted(chosen_fonts)])

# HTML("<div style='column-count: 2;'>{}</div>".format(code))

# Set default font
plt.rcParams['font.family'] = 'Arial'

# %%
# Styles
opt_header0 = dict(weight='regular', fontsize=8, alpha=.6, ha='center')
opt_name = dict(weight='bold', fontsize=24, ha='center', alpha = .8)
opt_contact = dict(weight='regular', fontsize=12, ha='center', alpha = .8)
opt_header = dict(weight='bold', fontsize=10.5, ha='right', color='red', alpha=.8)
opt_horline = dict(xmin=0.23, xmax=0.77, color='red', linewidth=1, alpha=.3)
opt_title = dict(weight='bold', fontsize=10.5, ha='left', alpha = .8)
opt_date = dict(style='italic', fontsize=10.5, ha='right', alpha = .8)
opt_desc = dict(weight='regular', fontsize=10.5, ha='left', alpha = .7)

# %% [markdown]
# # 3. Layout
# Add objects, modify size and position

# %%
fig, ax = plt.subplots(figsize=(8.3, 11.7))
ax.axis('off')

ax.annotate(header, (.5,.98), **opt_header0)
ax.annotate(name, (.5,.92), **opt_name)
ax.annotate(email + "  |  " + phone, (.5,.89), **opt_contact)

ax.annotate(header_edu, (.2,.85), **opt_header)
ax.annotate(edu_major, (.23,.85), **opt_title)
ax.annotate(edu_date, (.98,.85), **opt_date)
ax.annotate(edu_school, (.23,.83), **opt_title)

ax.annotate(header_work1, (.2,.79), **opt_header)
ax.annotate(header_work2, (.2,.77), **opt_header)
ax.annotate(work_title1, (.23,.79), **opt_title)
ax.annotate(work_title1_2, (.23,.77), **opt_title)
ax.annotate(work_date1, (.98,.79), **opt_date)
ax.annotate(work_place1, (.23,.75), **opt_title)
for count, value in enumerate(work_desc1.split('\n')):
    ax.annotate(value, (.23,.73-count*0.02), **opt_desc)
    
ax.annotate(work_title2 + '  |  ' + work_place2, (.23,.60), **opt_title)
ax.annotate(work_date2, (.98,.60), **opt_date)
for count, value in enumerate(work_desc2.split('\n')):
    ax.annotate(value, (.23,.58-count*0.02),  **opt_desc)
    
ax.annotate(work_title3, (.23,.51), **opt_title)
ax.annotate(work_date3, (.98,.51), **opt_date)
ax.annotate(work_place3, (.23,.49), **opt_title)
for count, value in enumerate(work_desc3.split('\n')):
    ax.annotate(value, (.23,.47-count*0.02),  **opt_desc)
    
ax.annotate(work_title4, (.23,.34), **opt_title)
ax.annotate(work_date4, (.98,.34), **opt_date)
ax.annotate(work_place4, (.23,.32), **opt_title)
for count, value in enumerate(work_desc4.split('\n')):
    ax.annotate(value, (.23,.30-count*0.02),  **opt_desc)
    
ax.annotate(header_skill, (.2,.20), **opt_header)
ax.annotate(header_skill2, (.2,.18), **opt_header)
ax.annotate(skill_title1 + '  |', (.23,.20), **opt_title)
ax.annotate(skill_title2 + '  |', (.23,.18), **opt_title)
ax.annotate(skill_title3 + '  |', (.23,.16), **opt_title)
ax.annotate(skill_desc1, (.41,.2),  **opt_desc)
ax.annotate(skill_desc2, (.48,.18),  **opt_desc)
ax.annotate(skill_desc3, (.38,.16),  **opt_desc)

ax.annotate(header_other, (.2,.12), **opt_header)
ax.annotate(other1, (.23,.12),  **opt_desc)

ax.annotate(header_cert, (.2,.08), **opt_header)
ax.annotate(cert_title1, (.23,.08), **opt_title)
ax.annotate(cert_title1_2, (.63,.08),  **opt_desc)
ax.annotate(cert_date1, (.98,.08), **opt_date)
ax.annotate(cert_date2, (.98,.06), **opt_date)
for count, value in enumerate(cert_title2.split('\n')):
    ax.annotate(value, (.23,0.06-count*0.02), **opt_title)
ax.annotate(cert_title1_2, (.685,.04),  **opt_desc)
    
# Lines
ax.axhline(y=.815, **opt_horline)
ax.axhline(y=.225, **opt_horline)
ax.axhline(y=.145, **opt_horline)
ax.axhline(y=.105, **opt_horline)

# save resume
plt.savefig('resume.pdf', bbox_inches='tight')
